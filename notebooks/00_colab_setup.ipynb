# %% [markdown]
# # 00 Colab setup
#
# Set up the CPR video POC worker on Google Colab using a Google Drive backed shared root.

# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
REPO_URL = '<YOUR_REPO_URL>'
WORKDIR = '/content/cpr-video-poc'
SHARED_ROOT = '/content/drive/MyDrive/cpr-video-poc-shared'

# %cd /content
# !rm -rf {WORKDIR}
# !git clone {REPO_URL} {WORKDIR}
# %cd {WORKDIR}
# !pip install -U pip
# !pip install -e .

# %%
from pathlib import Path

shared_root = Path(SHARED_ROOT)
shared_root.mkdir(parents=True, exist_ok=True)
(shared_root / 'jobs').mkdir(parents=True, exist_ok=True)
(shared_root / 'runs').mkdir(parents=True, exist_ok=True)
shared_root

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
